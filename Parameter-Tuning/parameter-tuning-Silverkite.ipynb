# %% [markdown]
# # Parameter Tuning - LinkedIn Silverkite

# %% [markdown]
# ## Libraries and Data

# %%
# Install Greykite - wrapper for Silverkite, Prophet, and ARIMA
# !pip install greykite

# %%
# Libraries
import numpy as np
import pandas as pd
from greykite.framework.templates.autogen.forecast_config import *
from greykite.framework.templates.forecaster import Forecaster
from greykite.framework.templates.model_templates import ModelTemplateEnum
from greykite.common.features.timeseries_features import *
from greykite.common.evaluation import EvaluationMetricEnum
from greykite.framework.utils.result_summary import summarize_grid_search_results
from plotly.offline import iplot

# %%
# Data
df = pd.read_csv('../Data/nyc-data.csv')
future_df = pd.read_csv('../Data/future.csv')
df
# Out:
#             Date      Demand  Easter  Thanksgiving  Christmas  Temperature  \
# 0       1/1/2015  720.000885       0             0          0         3.68
# 1       1/2/2015  581.276773       0             0          0         4.73
# 2       1/3/2015  754.117039       0             0          0         7.23
# 3       1/4/2015  622.252774       0             0          0        10.96
# 4       1/5/2015  785.373319       0             0          0         6.92
# ...          ...         ...     ...           ...        ...          ...
# 2187  12/27/2020  685.915026       0             0          0         2.89
# 2188  12/28/2020  998.051170       0             0          0         8.83
# 2189  12/29/2020  847.123399       0             0          0         3.48
# 2190  12/30/2020  857.521043       0             0          0         5.97
# 2191  12/31/2020  783.891494       0             0          0         8.22
#
#       Marketing
# 0        41.305
# 1       131.574
# 2       162.700
# 3       160.281
# 4        51.077
# ...         ...
# 2187     38.674
# 2188    166.712
# 2189    161.865
# 2190    179.634
# 2191    149.221
#
# [2192 rows x 7 columns]

# %%
future_df
# Out:
#          Date  Demand  Easter  Thanksgiving  Christmas  Temperature  Marketing
# 0    1/1/2021     NaN       0             0          0         5.00    154.221
# 1    1/2/2021     NaN       0             0          0        11.11    264.805
# 2    1/3/2021     NaN       0             0          0         3.89    115.499
# 3    1/4/2021     NaN       0             0          0         6.67    124.650
# 4    1/5/2021     NaN       0             0          0         5.56     77.968
# 5    1/6/2021     NaN       0             0          0         5.56    234.200
# 6    1/7/2021     NaN       0             0          0         6.11    142.041
# 7    1/8/2021     NaN       0             0          0         3.89    252.094
# 8    1/9/2021     NaN       0             0          0         2.78    100.483
# 9   1/10/2021     NaN       0             0          0         6.11     71.600
# 10  1/11/2021     NaN       0             0          0         3.33    122.091
# 11  1/12/2021     NaN       0             0          0         7.22    273.749
# 12  1/13/2021     NaN       0             0          0         6.67     42.638
# 13  1/14/2021     NaN       0             0          0        10.00    287.928
# 14  1/15/2021     NaN       0             0          0         8.33    127.720
# 15  1/16/2021     NaN       0             0          0         8.89    170.571
# 16  1/17/2021     NaN       0             0          0         7.78    172.633
# 17  1/18/2021     NaN       0             0          0         7.78    171.654
# 18  1/19/2021     NaN       0             0          0         6.11     57.343
# 19  1/20/2021     NaN       0             0          0         5.00     26.764
# 20  1/21/2021     NaN       0             0          0         7.22    154.601
# 21  1/22/2021     NaN       0             0          0         7.78     25.003
# 22  1/23/2021     NaN       0             0          0         2.78     75.534
# 23  1/24/2021     NaN       0             0          0         1.11    180.244
# 24  1/25/2021     NaN       0             0          0         3.89     44.421
# 25  1/26/2021     NaN       0             0          0         2.22    170.078
# 26  1/27/2021     NaN       0             0          0         3.33     39.664
# 27  1/28/2021     NaN       0             0          0         1.67    195.314
# 28  1/29/2021     NaN       0             0          0        -2.78    235.894
# 29  1/30/2021     NaN       0             0          0         1.11    152.752
# 30  1/31/2021     NaN       0             0          0         4.44    158.620

# %%
# Merging dataframes and reset index
df = pd.concat([df, future_df])
df = df.reset_index(drop=True)
df
# Out:
#            Date      Demand  Easter  Thanksgiving  Christmas  Temperature  \
# 0      1/1/2015  720.000885       0             0          0         3.68
# 1      1/2/2015  581.276773       0             0          0         4.73
# 2      1/3/2015  754.117039       0             0          0         7.23
# 3      1/4/2015  622.252774       0             0          0        10.96
# 4      1/5/2015  785.373319       0             0          0         6.92
# ...         ...         ...     ...           ...        ...          ...
# 2218  1/27/2021         NaN       0             0          0         3.33
# 2219  1/28/2021         NaN       0             0          0         1.67
# 2220  1/29/2021         NaN       0             0          0        -2.78
# 2221  1/30/2021         NaN       0             0          0         1.11
# 2222  1/31/2021         NaN       0             0          0         4.44
#
#       Marketing
# 0        41.305
# 1       131.574
# 2       162.700
# 3       160.281
# 4        51.077
# ...         ...
# 2218     39.664
# 2219    195.314
# 2220    235.894
# 2221    152.752
# 2222    158.620
#
# [2223 rows x 7 columns]

# %%
# Rename variable
df = df.rename(columns={'Demand': 'y'})
df.head(1)
# Out:
#        Date           y  Easter  Thanksgiving  Christmas  Temperature  \
# 0  1/1/2015  720.000885       0             0          0         3.68
#
#    Marketing
# 0     41.305

# %% [markdown]
# ## Silverkite Preparations

# %%
# Specifying time-series names (variables)
metadata = MetadataParam(time_col='Date',
                         value_col='y',
                         freq='D',
                         train_end_date=pd.to_datetime('2020-12-31'))
metadata
# Out:
# MetadataParam(anomaly_info=None, date_format=None, freq='D', time_col='Date', train_end_date=Timestamp('2020-12-31 00:00:00'), value_col='y')

# %% [markdown]
# ## Model Components
#
# * Growth terms: linear, quadratic, square root
#   * Reflect the shape of the trend curve (tune)
# * Seasonalities: yearly, quarterly, monthly, weekly, daily
#   * Daily data can have the higher 4 (auto)
# * Holidays/events: country holidays/other events
#   * Provided by model or user-generated (input)
# * Changepoints: When should the trend change
#   * Inflection points (auto)
# * Regressors: other influencing factors
#   * IVs that help model error (input)
# * Lagged Regressors: lagged effect of regressors
#   * Do they impact on a different day than they occur (auto)
# * Auto-regression: using the time-series itself
#   * Let past values predict the future (auto)

# %%
# Growth terms possibilities
growth = dict(growth_term = ['linear', 'quadratic', 'sqrt'])
growth
# Out:
# {'growth_term': ['linear', 'quadratic', 'sqrt']}

# %%
# Seasonalities
seasonality = dict(yearly_seasonality = 'auto',  # Can also set to None or True
                   quarterly_seasonality = 'auto',  # 'auto' lets the model figure it out
                   monthly_seasonality = 'auto',
                   weekly_seasonality = 'auto',
                   daily_seasonality = 'auto')  # Can include hourly_seasonality if you have hourly data
seasonality
# Out:
# {'yearly_seasonality': 'auto',
#  'quarterly_seasonality': 'auto',
#  'monthly_seasonality': 'auto',
#  'weekly_seasonality': 'auto',
#  'daily_seasonality': 'auto'}

# %%
# Checking which countries are available for holidays
get_available_holiday_lookup_countries(['US'])  # May need to use different format for country
# Out:
# ['US']

# %%
get_available_holidays_across_countries(countries=['US'],
                                        year_start=2015,
                                        year_end=2021)
# Out:
# ['Christmas Day',
#  'Christmas Day (Observed)',
#  'Columbus Day',
#  'Halloween',
#  'Independence Day',
#  'Independence Day (Observed)',
#  'Juneteenth National Independence Day',
#  'Juneteenth National Independence Day (Observed)',
#  'Labor Day',
#  'Martin Luther King Jr. Day',
#  'Memorial Day',
#  "New Year's Day",
#  "New Year's Day (Observed)",
#  'Thanksgiving',
#  'Veterans Day',
#  'Veterans Day (Observed)',
#  "Washington's Birthday"]

# %%
# Specifying events
events = dict(holidays_to_model_separately = ["New Year's Day"],  # Can include others in list if desired
              holiday_lookup_countries = ['US'],
              holiday_pre_num_days = 2,
              holiday_post_num_days = 2,
              holiday_pre_post_num_dict = {"New Year's Day": (3, 1)},  # Include a term for all separate holidays
              daily_event_df_dict = {"elections": pd.DataFrame({  # Adding your own event
                  'date': ['2016-11-08', '2020-11-03'],
                  'event_name': ['elections'] * 2
              })})
events
# Out:
# {'holidays_to_model_separately': ["New Year's Day"],
#  'holiday_lookup_countries': ['US'],
#  'holiday_pre_num_days': 2,
#  'holiday_post_num_days': 2,
#  'holiday_pre_post_num_dict': {"New Year's Day": (3, 1)},
#  'daily_event_df_dict': {'elections':          date event_name
#   0  2016-11-08  elections
#   1  2020-11-03  elections}}

# %%
# Changepoints -> reflects changes in trend
changepoints = dict(changepoints_dict = dict(method = 'auto'))
changepoints
# Out:
# {'changepoints_dict': {'method': 'auto'}}

# %%
# Regressors (don't include them unless you know they have an impact)
regressors = dict(regressor_cols = ['Easter', 'Temperature', 'Marketing'])
regressors
# Out:
# {'regressor_cols': ['Easter', 'Temperature', 'Marketing']}

# %%
# Lagged Regressors (depends on forecasting horizon)
lagged_regressors = dict(lagged_regressor_dict = {'Temperature': 'auto',
                                                  'Easter': 'auto',
                                                  'Marketing': 'auto'})
lagged_regressors
# Out:
# {'lagged_regressor_dict': {'Temperature': 'auto',
#   'Easter': 'auto',
#   'Marketing': 'auto'}}

# %%
# Auto-regression (depends on forecasting horizon)
autoregression = dict(autoreg_dict = 'auto')
autoregression
# Out:
# {'autoreg_dict': 'auto'}

# %% [markdown]
# ## Fitting Algorithms
#
# 9 possibilities:
#
# 1. Linear regression* - poor with collinearity
# 2. Elastic Net
# 3. Ridge*
# 4. Lasso
# 5. Stochastic Gradient Descent - unstable
# 6. Lars - outlier/noise sensitivity
# 7. Lasso Lars
# 8. Random Forest* - tree models don't model growth well
# 9. Gradient Boosting* - tree models don't model growth well
#
# We'll try the starred* ones.

# %%
# Fitting algorithms

custom = dict(fit_algorithm_dict = [dict(fit_algorithm = 'linear'),
                                    dict(fit_algorithm = 'ridge'),
                                    dict(fit_algorithm = 'rf'),
                                    dict(fit_algorithm = 'gradient_boosting')])
custom
# Out:
# {'fit_algorithm_dict': [{'fit_algorithm': 'linear'},
#   {'fit_algorithm': 'ridge'},
#   {'fit_algorithm': 'rf'},
#   {'fit_algorithm': 'gradient_boosting'}]}

# %% [markdown]
# ## Silverkite Model

# %%
# Build the model
model_components = ModelComponentsParam(growth=growth,
                                        seasonality=seasonality,
                                        events=events,
                                        changepoints=changepoints,
                                        regressors=regressors,
                                        lagged_regressors=lagged_regressors,
                                        autoregression=autoregression,
                                        custom=custom)
model_components
# Out:
# ModelComponentsParam(autoregression={'autoreg_dict': 'auto'}, changepoints={'changepoints_dict': {'method': 'auto'}}, custom={'fit_algorithm_dict': [{'fit_algorithm': 'linear'}, {'fit_algorithm': 'ridge'}, {'fit_algorithm': 'rf'}, {'fit_algorithm': 'gradient_boosting'}]}, events={'holidays_to_model_separately': ["New Year's Day"], 'holiday_lookup_countries': ['US'], 'holiday_pre_num_days': 2, 'holiday_post_num_days': 2, 'holiday_pre_post_num_dict': {"New Year's Day": (3, 1)}, 'daily_event_df_dict': {'elections':          date event_name
# 0  2016-11-08  elections
# 1  2020-11-03  elections}}, growth={'growth_term': ['linear', 'quadratic', 'sqrt']}, hyperparameter_override=None, regressors={'regressor_cols': ['Easter', 'Temperature', 'Marketing']}, lagged_regressors={'lagged_regressor_dict': {'Temperature': 'auto', 'Easter': 'auto', 'Marketing': 'auto'}}, seasonality={'yearly_seasonality': 'auto', 'quarterly_seasonality': 'auto', 'monthly_seasonality': 'auto', 'weekly_seasonality': 'auto', 'daily_seasonality': 'auto'}, uncertainty=None)

# %%
# Cross-validation
evaluation_period = EvaluationPeriodParam(cv_min_train_periods=df.shape[0] - 180 - 31,
                                          cv_expanding_window=True,
                                          cv_max_splits=50,  # Ideally should be None, but there were problems with that
                                          cv_periods_between_splits=16)

# %%
# Evaluation metric
evaluation_metric = EvaluationMetricParam(
    cv_selection_metric=EvaluationMetricEnum.RootMeanSquaredError.name)

# %%
# Configuration
config = ForecastConfig(model_template=ModelTemplateEnum.SILVERKITE.name,
                        forecast_horizon=31,
                        metadata_param=metadata,
                        model_components_param=model_components,
                        evaluation_period_param=evaluation_period,
                        evaluation_metric_param=evaluation_metric)

# %%
# Forecasting
forecaster = Forecaster()
result = forecaster.run_forecast_config(df=df,
                                        config=config)

# %%
# Visualization
fig = result.backtest.plot()
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5190c4b9-bad4-446d-a2c2-5e7582f6ef48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5190c4b9-bad4-446d-a2c2-5e7582f6ef48")) {                    Plotly.newPlot(                        "5190c4b9-bad4-446d-a2c2-5e7582f6ef48",                        [{"line":{"color":"rgba(250, 43, 20, 0.7)"},"marker":{"color":"rgba(250, 43, 20, 0.7)","size":2.0},"mode":"lines+markers","name":"Actual","opacity":1.0,"x":["2015-01-01T00:00:00","2015-01-02T00:00:00","2015-01-03T00:00:00","2015-01-04T00:00:00","2015-01-05T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-10T00:00:00","2015-01-11T00:00:00","2015-01-12T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-17T00:00:00","2015-01-18T00:00:00","2015-01-19T00:00:00","2015-01-20T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-24T00:00:00","2015-01-25T00:00:00","2015-01-26T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-01-31T00:00:00","2015-02-01T00:00:00","2015-02-02T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-07T00:00:00","2015-02-08T00:00:00","2015-02-09T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-14T00:00:00","2015-02-15T00:00:00","2015-02-16T00:00:00","2015-02-17T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-21T00:00:00","2015-02-22T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-02-28T00:00:00","2015-03-01T00:00:00","2015-03-02T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-07T00:00:00","2015-03-08T00:00:00","2015-03-09T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-14T00:00:00","2015-03-15T00:00:00","2015-03-16T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-21T00:00:00","2015-03-22T00:00:00","2015-03-23T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-28T00:00:00","2015-03-29T00:00:00","2015-03-30T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2015-04-03T00:00:00","2015-04-04T00:00:00","2015-04-05T00:00:00","2015-04-06T00:00:00","2015-04-07T00:00:00","2015-04-08T00:00:00","2015-04-09T00:00:00","2015-04-10T00:00:00","2015-04-11T00:00:00","2015-04-12T00:00:00","2015-04-13T00:00:00","2015-04-14T00:00:00","2015-04-15T00:00:00","2015-04-16T00:00:00","2015-04-17T00:00:00","2015-04-18T00:00:00","2015-04-19T00:00:00","2015-04-20T00:00:00","2015-04-21T00:00:00","2015-04-22T00:00:00","2015-04-23T00:00:00","2015-04-24T00:00:00","2015-04-25T00:00:00","2015-04-26T00:00:00","2015-04-27T00:00:00","2015-04-28T00:00:00","2015-04-29T00:00:00","2015-04-30T00:00:00","2015-05-01T00:00:00","2015-05-02T00:00:00","2015-05-03T00:00:00","2015-05-04T00:00:00","2015-05-05T00:00:00","2015-05-06T00:00:00","2015-05-07T00:00:00","2015-05-08T00:00:00","2015-05-09T00:00:00","2015-05-10T00:00:00","2015-05-11T00:00:00","2015-05-12T00:00:00","2015-05-13T00:00:00","2015-05-14T00:00:00","2015-05-15T00:00:00","2015-05-16T00:00:00","2015-05-17T00:00:00","2015-05-18T00:00:00","2015-05-19T00:00:00","2015-05-20T00:00:00","2015-05-21T00:00:00","2015-05-22T00:00:00","2015-05-23T00:00:00","2015-05-24T00:00:00","2015-05-25T00:00:00","2015-05-26T00:00:00","2015-05-27T00:00:00","2015-05-28T00:00:00","2015-05-29T00:00:00","2015-05-30T00:00: ...

# %% [markdown]
# ## Parameter Tuning Results

# %%
# CV results
cv_results = summarize_grid_search_results(
    grid_search=result.grid_search,
    decimals=1,
    score_func=EvaluationMetricEnum.RootMeanSquaredError.name)

# %%
# Set the CV results index
cv_results['params'] = cv_results['params'].astype(str)
cv_results.set_index('params', drop=True, inplace=True)
cv_results
# Out:
#                                                     rank_test_CORR  \
# params
# [('estimator__growth_term', 'linear'), ('estima...               2
# [('estimator__growth_term', 'quadratic'), ('est...               1
# [('estimator__growth_term', 'sqrt'), ('estimato...               3
# [('estimator__growth_term', 'linear'), ('estima...               5
# [('estimator__growth_term', 'quadratic'), ('est...               4
# [('estimator__growth_term', 'sqrt'), ('estimato...               6
# [('estimator__growth_term', 'linear'), ('estima...              12
# [('estimator__growth_term', 'quadratic'), ('est...              11
# [('estimator__growth_term', 'sqrt'), ('estimato...              10
# [('estimator__growth_term', 'linear'), ('estima...               9
# [('estimator__growth_term', 'quadratic'), ('est...               7
# [('estimator__growth_term', 'sqrt'), ('estimato...               8
#
#                                                     rank_test_R2  \
# params
# [('estimator__growth_term', 'linear'), ('estima...             1
# [('estimator__growth_term', 'quadratic'), ('est...             2
# [('estimator__growth_term', 'sqrt'), ('estimato...             3
# [('estimator__growth_term', 'linear'), ('estima...             6
# [('estimator__growth_term', 'quadratic'), ('est...             4
# [('estimator__growth_term', 'sqrt'), ('estimato...             5
# [('estimator__growth_term', 'linear'), ('estima...            12
# [('estimator__growth_term', 'quadratic'), ('est...            11
# [('estimator__growth_term', 'sqrt'), ('estimato...            10
# [('estimator__growth_term', 'linear'), ('estima...             7
# [('estimator__growth_term', 'quadratic'), ('est...             9
# [('estimator__growth_term', 'sqrt'), ('estimato...             8
#
#                                                     rank_test_MSE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...              1
# [('estimator__growth_term', 'quadratic'), ('est...              2
# [('estimator__growth_term', 'sqrt'), ('estimato...              3
# [('estimator__growth_term', 'linear'), ('estima...              6
# [('estimator__growth_term', 'quadratic'), ('est...              4
# [('estimator__growth_term', 'sqrt'), ('estimato...              5
# [('estimator__growth_term', 'linear'), ('estima...             12
# [('estimator__growth_term', 'quadratic'), ('est...             11
# [('estimator__growth_term', 'sqrt'), ('estimato...             10
# [('estimator__growth_term', 'linear'), ('estima...              7
# [('estimator__growth_term', 'quadratic'), ('est...              9
# [('estimator__growth_term', 'sqrt'), ('estimato...              8
#
#                                                     rank_test_RMSE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...               1
# [('estimator__growth_term', 'quadratic'), ('est...               2
# [('estimator__growth_term', 'sqrt'), ('estimato...               3
# [('estimator__growth_term', 'linear'), ('estima...               6
# [('estimator__growth_term', 'quadratic'), ('est...               4
# [('estimator__growth_term', 'sqrt'), ('estimato...               5
# [('estimator__growth_term', 'linear'), ('estima...              12
# [('estimator__growth_term', 'quadratic'), ('est...              11
# [('estimator__growth_term', 'sqrt'), ('estimato...              10
# [('estimator__growth_term', 'linear'), ('estima...               7
# [('estimator__growth_term', 'quadratic'), ('est...               9
# [('estimator__growth_term', 'sqrt'), ('estimato...               8
#
#                                                     rank_test_MAE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...              1
# [('estimator__growth_term', 'quadratic'), ('est...              3
# [('estimator__growth_term', 'sqrt'), ('estimato...              2
# [('estimator__growth_term', 'linear'), ('estima...              6
# [('estimator__growth_term', 'quadratic'), ('est...              4
# [('estimator__growth_term', 'sqrt'), ('estimato...              5
# [('estimator__growth_term', 'linear'), ('estima...             12
# [('estimator__growth_term', 'quadratic'), ('est...             11
# [('estimator__growth_term', 'sqrt'), ('estimato...             10
# [('estimator__growth_term', 'linear'), ('estima...              7
# [('estimator__growth_term', 'quadratic'), ('est...              9
# [('estimator__growth_term', 'sqrt'), ('estimato...              8
#
#                                                     rank_test_MedAE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                2
# [('estimator__growth_term', 'quadratic'), ('est...                1
# [('estimator__growth_term', 'sqrt'), ('estimato...                3
# [('estimator__growth_term', 'linear'), ('estima...                6
# [('estimator__growth_term', 'quadratic'), ('est...                4
# [('estimator__growth_term', 'sqrt'), ('estimato...                5
# [('estimator__growth_term', 'linear'), ('estima...               12
# [('estimator__growth_term', 'quadratic'), ('est...               11
# [('estimator__growth_term', 'sqrt'), ('estimato...               10
# [('estimator__growth_term', 'linear'), ('estima...                7
# [('estimator__growth_term', 'quadratic'), ('est...                9
# [('estimator__growth_term', 'sqrt'), ('estimato...                8
#
#                                                     rank_test_MAPE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...               1
# [('estimator__growth_term', 'quadratic'), ('est...               3
# [('estimator__growth_term', 'sqrt'), ('estimato...               2
# [('estimator__growth_term', 'linear'), ('estima...               5
# [('estimator__growth_term', 'quadratic'), ('est...               4
# [('estimator__growth_term', 'sqrt'), ('estimato...               6
# [('estimator__growth_term', 'linear'), ('estima...              12
# [('estimator__growth_term', 'quadratic'), ('est...              11
# [('estimator__growth_term', 'sqrt'), ('estimato...              10
# [('estimator__growth_term', 'linear'), ('estima...               7
# [('estimator__growth_term', 'quadratic'), ('est...               9
# [('estimator__growth_term', 'sqrt'), ('estimato...               8
#
#                                                     rank_test_MedAPE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                 1
# [('estimator__growth_term', 'quadratic'), ('est...                 3
# [('estimator__growth_term', 'sqrt'), ('estimato...                 2
# [('estimator__growth_term', 'linear'), ('estima...                 6
# [('estimator__growth_term', 'quadratic'), ('est...                 4
# [('estimator__growth_term', 'sqrt'), ('estimato...                 5
# [('estimator__growth_term', 'linear'), ('estima...                12
# [('estimator__growth_term', 'quadratic'), ('est...                10
# [('estimator__growth_term', 'sqrt'), ('estimato...                11
# [('estimator__growth_term', 'linear'), ('estima...                 7
# [('estimator__growth_term', 'quadratic'), ('est...                 9
# [('estimator__growth_term', 'sqrt'), ('estimato...                 8
#
#                                                     rank_test_sMAPE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                1
# [('estimator__growth_term', 'quadratic'), ('est...                3
# [('estimator__growth_term', 'sqrt'), ('estimato...                2
# [('estimator__growth_term', 'linear'), ('estima...                6
# [('estimator__growth_term', 'quadratic'), ('est...                4
# [('estimator__growth_term', 'sqrt'), ('estimato...                5
# [('estimator__growth_term', 'linear'), ('estima...               12
# [('estimator__growth_term', 'quadratic'), ('est...               11
# [('estimator__growth_term', 'sqrt'), ('estimato...               10
# [('estimator__growth_term', 'linear'), ('estima...                7
# [('estimator__growth_term', 'quadratic'), ('est...                9
# [('estimator__growth_term', 'sqrt'), ('estimato...                8
#
#                                                     rank_test_Q80  ...  \
# params                                                             ...
# [('estimator__growth_term', 'linear'), ('estima...              6  ...
# [('estimator__growth_term', 'quadratic'), ('est...              5  ...
# [('estimator__growth_term', 'sqrt'), ('estimato...              7  ...
# [('estimator__growth_term', 'linear'), ('estima...             12  ...
# [('estimator__growth_term', 'quadratic'), ('est...             10  ...
# [('estimator__growth_term', 'sqrt'), ('estimato...             11  ...
# [('estimator__growth_term', 'linear'), ('estima...              8  ...
# [('estimator__growth_term', 'quadratic'), ('est...              4  ...
# [('estimator__growth_term', 'sqrt'), ('estimato...              9  ...
# [('estimator__growth_term', 'linear'), ('estima...              1  ...
# [('estimator__growth_term', 'quadratic'), ('est...              2  ...
# [('estimator__growth_term', 'sqrt'), ('estimato...              3  ...
#
#                                                     std_test_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                          0.1
# [('estimator__growth_term', 'quadratic'), ('est...                          0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                          0.1
# [('estimator__growth_term', 'linear'), ('estima...                          0.0
# [('estimator__growth_term', 'quadratic'), ('est...                          0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                          0.0
# [('estimator__growth_term', 'linear'), ('estima...                          0.1
# [('estimator__growth_term', 'quadratic'), ('est...                          0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                          0.1
# [('estimator__growth_term', 'linear'), ('estima...                          0.1
# [('estimator__growth_term', 'quadratic'), ('est...                          0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                          0.1
#
#                                                     split0_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.5
# [('estimator__growth_term', 'quadratic'), ('est...                              0.5
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.5
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     split1_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.5
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.5
# [('estimator__growth_term', 'linear'), ('estima...                              0.5
# [('estimator__growth_term', 'quadratic'), ('est...                              0.5
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.5
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     split2_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     split3_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     split4_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     split5_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     split6_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     split7_train_OutsideTolerance5p  \
# params
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
# [('estimator__growth_term', 'linear'), ('estima...                              0.1
# [('estimator__growth_term', 'quadratic'), ('est...                              0.1
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.1
# [('estimator__growth_term', 'linear'), ('estima...                              0.4
# [('estimator__growth_term', 'quadratic'), ('est...                              0.4
# [('estimator__growth_term', 'sqrt'), ('estimato...                              0.4
#
#                                                     std_train_OutsideTolerance5p
# params
# [('estimator__growth_term', 'linear'), ('estima...                           0.0
# [('estimator__growth_term', 'quadratic'), ('est...                           0.0
# [('estimator__growth_term', 'sqrt'), ('estimato...                           0.0
# [('estimator__growth_term', 'linear'), ('estima...                           0.0
# [('estimator__growth_term', 'quadratic'), ('est...                           0.0
# [('estimator__growth_term', 'sqrt'), ('estimato...                           0.0
# [('estimator__growth_term', 'linear'), ('estima...                           0.0
# [('estimator__growth_term', 'quadratic'), ('est...                           0.0
# [('estimator__growth_term', 'sqrt'), ('estimato...                           0.0
# [('estimator__growth_term', 'linear'), ('estima...                           0.0
# [('estimator__growth_term', 'quadratic'), ('est...                           0.0
# [('estimator__growth_term', 'sqrt'), ('estimato...                           0.0
#
# [12 rows x 436 columns]

# %%
# Looking at the best results
cv_results[['rank_test_RMSE', 'mean_test_RMSE',
            'param_estimator__fit_algorithm_dict',
            'param_estimator__growth_term']]
# Out:
#                                                     rank_test_RMSE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...               1
# [('estimator__growth_term', 'quadratic'), ('est...               2
# [('estimator__growth_term', 'sqrt'), ('estimato...               3
# [('estimator__growth_term', 'linear'), ('estima...               6
# [('estimator__growth_term', 'quadratic'), ('est...               4
# [('estimator__growth_term', 'sqrt'), ('estimato...               5
# [('estimator__growth_term', 'linear'), ('estima...              12
# [('estimator__growth_term', 'quadratic'), ('est...              11
# [('estimator__growth_term', 'sqrt'), ('estimato...              10
# [('estimator__growth_term', 'linear'), ('estima...               7
# [('estimator__growth_term', 'quadratic'), ('est...               9
# [('estimator__growth_term', 'sqrt'), ('estimato...               8
#
#                                                     mean_test_RMSE  \
# params
# [('estimator__growth_term', 'linear'), ('estima...            47.8
# [('estimator__growth_term', 'quadratic'), ('est...            47.8
# [('estimator__growth_term', 'sqrt'), ('estimato...            47.9
# [('estimator__growth_term', 'linear'), ('estima...            48.9
# [('estimator__growth_term', 'quadratic'), ('est...            48.5
# [('estimator__growth_term', 'sqrt'), ('estimato...            48.9
# [('estimator__growth_term', 'linear'), ('estima...            64.8
# [('estimator__growth_term', 'quadratic'), ('est...            64.3
# [('estimator__growth_term', 'sqrt'), ('estimato...            63.6
# [('estimator__growth_term', 'linear'), ('estima...            56.6
# [('estimator__growth_term', 'quadratic'), ('est...            58.0
# [('estimator__growth_term', 'sqrt'), ('estimato...            56.7
#
#                                                        param_estimator__fit_algorithm_dict  \
# params
# [('estimator__growth_term', 'linear'), ('estima...             {'fit_algorithm': 'linear'}
# [('estimator__growth_term', 'quadratic'), ('est...             {'fit_algorithm': 'linear'}
# [('estimator__growth_term', 'sqrt'), ('estimato...             {'fit_algorithm': 'linear'}
# [('estimator__growth_term', 'linear'), ('estima...              {'fit_algorithm': 'ridge'}
# [('estimator__growth_term', 'quadratic'), ('est...              {'fit_algorithm': 'ridge'}
# [('estimator__growth_term', 'sqrt'), ('estimato...              {'fit_algorithm': 'ridge'}
# [('estimator__growth_term', 'linear'), ('estima...                 {'fit_algorithm': 'rf'}
# [('estimator__growth_term', 'quadratic'), ('est...                 {'fit_algorithm': 'rf'}
# [('estimator__growth_term', 'sqrt'), ('estimato...                 {'fit_algorithm': 'rf'}
# [('estimator__growth_term', 'linear'), ('estima...  {'fit_algorithm': 'gradient_boosting'}
# [('estimator__growth_term', 'quadratic'), ('est...  {'fit_algorithm': 'gradient_boosting'}
# [('estimator__growth_term', 'sqrt'), ('estimato...  {'fit_algorithm': 'gradient_boosting'}
#
#                                                    param_estimator__growth_term
# params
# [('estimator__growth_term', 'linear'), ('estima...                       linear
# [('estimator__growth_term', 'quadratic'), ('est...                    quadratic
# [('estimator__growth_term', 'sqrt'), ('estimato...                         sqrt
# [('estimator__growth_term', 'linear'), ('estima...                       linear
# [('estimator__growth_term', 'quadratic'), ('est...                    quadratic
# [('estimator__growth_term', 'sqrt'), ('estimato...                         sqrt
# [('estimator__growth_term', 'linear'), ('estima...                       linear
# [('estimator__growth_term', 'quadratic'), ('est...                    quadratic
# [('estimator__growth_term', 'sqrt'), ('estimato...                         sqrt
# [('estimator__growth_term', 'linear'), ('estima...                       linear
# [('estimator__growth_term', 'quadratic'), ('est...                    quadratic
# [('estimator__growth_term', 'sqrt'), ('estimato...                         sqrt

# %%
# Get best parameters
best_params = cv_results[cv_results.rank_test_RMSE == 1][['mean_test_RMSE',
                                                          'param_estimator__fit_algorithm_dict',
                                                          'param_estimator__growth_term']].transpose()
best_params
# Out:
# params                              [('estimator__growth_term', 'linear'), ('estimator__fit_algorithm_dict', {'fit_algorithm': 'linear'})]
# mean_test_RMSE                                                                    47.8
# param_estimator__fit_algorithm_dict                        {'fit_algorithm': 'linear'}
# param_estimator__growth_term                                                    linear

# %%
best_params.to_csv('../Forecasting-Product/best-params-silverkite.csv')
